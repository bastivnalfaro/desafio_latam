# %% [markdown]
# Cargamos librerias y ruta en donde esta el archivo que necesitamos analizar

# %%
import zipfile #interactuar con archivos comprimidos
import json #interactuar con json
from typing import List, Tuple #resultados en listas o tuplas
from collections import Counter #contar ocurrencias
from datetime import datetime #trabajar con fechas
import pandas as pd #interactuar con la data
import emoji #interactuar con los emojis
from memory_profiler import profile #revisar consumo de memoria
import time #trabajar con tiempo
import cProfile #revisar consumo de tiempo

file_path = r"C:\Users\bastian\Downloads\tweets.json.zip"

# %% [markdown]
# # Ejercicio 1:  Las top 10 fechas donde hay más tweets. Mencionar el usuario que más publicaciones tiene por cada uno de esos días.

# %%
# =============================================================================
# Ejercicio 1: Función enfocada al tiempo
# =============================================================================

def q1_time(file_path: str) -> List[Tuple[datetime.date, str]]:
    start_time = time.time()  # Iniciar la medición de tiempo
    # Lista para almacenar los datos JSON
    data = []

    # Abre el archivo ZIP
    with zipfile.ZipFile(file_path, 'r') as zip_file:
        with zip_file.open('farmers-protest-tweets-2021-2-4.json') as json_file:
            data = [json.loads(line.decode('utf-8')) for line in json_file]    

    
    # Convierte la lista de datos en un DataFrame de Pandas
    df = pd.DataFrame(data)
    
    # Agrupar por fecha y contar el número de tweets por fecha y usuario
    df['date'] = pd.to_datetime(df['date'])
    df['username'] = df['user'].apply(lambda x: x['username'])
    grouped = df.groupby([df['date'].dt.date, 'username']).size().reset_index(name='count')
    
    # Obtener las 10 fechas con más tweets
    top_dates = grouped.groupby('date')['count'].sum().nlargest(10).index
    
    # Obtener el usuario con más publicaciones para cada fecha
    result = []
    for date in top_dates:
        top_user = grouped[grouped['date'] == date].nlargest(1, 'count')
        result.append((date, top_user['username'].values[0]))

    end_time = time.time()  # Finalizar la medición de tiempo
    print(f"Tiempo de ejecución: {end_time - start_time} segundos")

    return result

# %%
# =============================================================================
# Resultados: Ejercicio 1 (tiempo)
# =============================================================================
if __name__ == "__main__":
    profiler = cProfile.Profile()
    result = profiler.runcall(q1_time, file_path)
    print(result)
    print("\n")
    profiler.print_stats()
# Out:
# Tiempo de ejecución: 13.558779001235962 segundos
# [(datetime.date(2021, 2, 12), 'RanbirS00614606'), (datetime.date(2021, 2, 13), 'MaanDee08215437'), (datetime.date(2021, 2, 17), 'RaaJVinderkaur'), (datetime.date(2021, 2, 16), 'jot__b'), (datetime.date(2021, 2, 14), 'rebelpacifist'), (datetime.date(2021, 2, 18), 'neetuanjle_nitu'), (datetime.date(2021, 2, 15), 'jot__b'), (datetime.date(2021, 2, 20), 'MangalJ23056160'), (datetime.date(2021, 2, 23), 'Surrypuria'), (datetime.date(2021, 2, 19), 'Preetm91')]
#
#
#          6861266 function calls (6860478 primitive calls) in 13.559 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.198    0.198   12.145   12.145 1746901351.py:13(<listcomp>)
#    117407    0.030    0.000    0.030    0.000 1746901351.py:21(<lambda>)
#         1    0.031    0.031   13.559   13.559 1746901351.py:5(q1_time)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(all)
#         6    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(append)
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(argsort)
#        22    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(array_equal)
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(atleast_2d)
#         4    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(bincount)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(can_cast)
#        47    0.000    0.000    0.035    0.001 <__array_function__ internals>:177(concatenate)
#        45    0.000    0.000    0.001    0.000 <__array_function__ internals>:177(copyto)
#         3    0.000    0.000    0.031    0.010 <__array_function__ internals>:177(delete)
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(insert)
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(moveaxis)
#        11    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(nonzero)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(prod)
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(putmask)
#         6    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(ravel)
#         3    0.000    0.000    0.034    0.011 <__array_function__ internals>:177(vstack)
#         1    0.000    0.000    0.000    0.000 <frozen _collections_abc>:262(__subclasshook__)
#        13    0.000    0.000    0.000    0.000 <frozen _collections_abc>:315(__subclasshook__)
#         1    0.000    0.000    0.000    0.000 <frozen _collections_abc>:381(__subclasshook__)
#        52    0.000    0.000    0.000    0.000 <frozen _collections_abc>:409(__subclasshook__)
#         3    0.000    0.000    0.000    0.000 <frozen _collections_abc>:78(_check_methods)
#        28    0.000    0.000    0.001    0.000 <frozen abc>:117(__instancecheck__)
#     73/10    0.000    0.000    0.000    0.000 <frozen abc>:121(__subclasscheck__)
#         1    0.000    0.000    0.000    0.000 <frozen codecs>:1064(make_identity_dict)
#         1    0.000    0.000    0.000    0.000 <frozen codecs>:1072(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 <frozen codecs>:94(__new__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:100(acquire)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1026(__enter__)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1030(__exit__)
#         1    0.000    0.000    0.001    0.001 <frozen importlib._bootstrap>:1054(_find_spec)
#         1    0.000    0.000    0.004    0.004 <frozen importlib._bootstrap>:1120(_find_and_load_unlocked)
#         1    0.000    0.000    0.004    0.004 <frozen importlib._bootstrap>:1165(_find_and_load)
#        48    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1207(_handle_fromlist)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:125(release)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:165(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:169(__enter__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:173(__exit__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:179(_get_module_lock)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:198(cb)
#         2    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:233(_call_with_frames_removed)
#         6    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:244(_verbose_message)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:357(__init__)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:392(cached)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:405(parent)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:413(has_location)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:48(_new_module)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:493(_init_module_attrs)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:566(module_from_spec)
#         1    0.000    0.000    0.003    0.003 <frozen importlib._bootstrap>:666(_load_unlocked)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:71(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:748(find_spec)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:920(find_spec)
#         1    0.000    0.000    0.002    0.002 <frozen importlib._bootstrap_external>:1007(get_code)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1097(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1122(get_filename)
#         1    0.000    0.000    0.001    0.001 <frozen importlib._bootstrap_external>:1127(get_data)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1146(path_stats)
#         5    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:119(<listcomp>)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:132(_path_split)
#         6    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:134(<genexpr>)
#         3    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:140(_path_stat)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1421(_path_importer_cache)
#         1    0.000    0.000    0.001    0.001 <frozen importlib._bootstrap_external>:1464(_get_spec)
#         1    0.000    0.000    0.001    0.001 <frozen importlib._bootstrap_external>:1496(find_spec)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:150(_path_is_mode_type)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:159(_path_isfile)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1599(_get_spec)
#         1    0.000    0.000    0.001    0.001 <frozen importlib._bootstrap_external>:1604(find_spec)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:172(_path_isabs)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:437(cache_from_source)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:567(_get_cached)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:599(_check_name_wrapper)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:642(_classify_pyc)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:67(_relax_case)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:675(_validate_timestamp_pyc)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:727(_compile_bytecode)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:778(spec_from_file_location)
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:84(_unpack_uint32)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:931(create_module)
#         1    0.000    0.000    0.003    0.003 <frozen importlib._bootstrap_external>:934(exec_module)
#         5    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:96(_path_join)
#         1    0.000    0.000    0.000    0.000 <frozen os>:1081(__subclasshook__)
#         2    0.000    0.000    0.000    0.000 <frozen os>:674(__getitem__)
#         2    0.000    0.000    0.000    0.000 <frozen os>:742(check_str)
#         2    0.000    0.000    0.000    0.000 <frozen os>:748(encodekey)
#        29    0.000    0.000    0.001    0.000 __init__.py:225(compile)
#         1    0.000    0.000    0.000    0.000 __init__.py:261(__str__)
#        29    0.000    0.000    0.001    0.000 __init__.py:272(_compile)
#    117407    0.160    0.000    5.620    0.000 __init__.py:299(loads)
#         1    0.000    0.000    0.000    0.000 __init__.py:43(normalize_encoding)
#    117408    0.017    0.000    0.017    0.000 __init__.py:440(FixedOffset)
#         1    0.000    0.000    0.005    0.005 __init__.py:71(search_function)
#         1    0.000    0.000    0.000    0.000 __init__.py:89(find_spec)
#         5    0.000    0.000    0.000    0.000 _asarray.py:112(<setcomp>)
#         5    0.000    0.000    0.000    0.000 _asarray.py:31(require)
#       2/1    0.000    0.000    0.000    0.000 _compiler.py:37(_compile)
#         1    0.000    0.000    0.000    0.000 _compiler.py:396(_simple)
#         2    0.000    0.000    0.000    0.000 _compiler.py:426(_get_iscased)
#         1    0.000    0.000    0.000    0.000 _compiler.py:434(_get_literal_prefix)
#         1    0.000    0.000    0.000    0.000 _compiler.py:465(_get_charset_prefix)
#         1    0.000    0.000    0.000    0.000 _compiler.py:509(_compile_info)
#         2    0.000    0.000    0.000    0.000 _compiler.py:568(isstring)
#         1    0.000    0.000    0.000    0.000 _compiler.py:571(_code)
#         1    0.000    0.000    0.000    0.000 _compiler.py:738(compile)
#     69/46    0.000    0.000    0.020    0.000 _decorators.py:323(wrapper)
#        28    0.000    0.000    0.000    0.000 _dtype.py:24(_kind_name)
#        28    0.000    0.000    0.000    0.000 _dtype.py:330(_name_includes_bit_suffix)
#        28    0.000    0.000    0.000    0.000 _dtype.py:344(_name_get)
#         2    0.000    0.000    0.000    0.000 _methods.py:39(_amax)
#         2    0.000    0.000    0.000    0.000 _methods.py:43(_amin)
#        84    0.000    0.000    0.000    0.000 _methods.py:55(_any)
#        22    0.000    0.000    0.000    0.000 _methods.py:61(_all)
#         2    0.000    0.000    0.000    0.000 _mixins.py:283(__getitem__)
#         2    0.000    0.000    0.000    0.000 _parser.py:109(__init__)
#         4    0.000    0.000    0.000    0.000 _parser.py:158(__len__)
#        29    0.000    0.000    0.000    0.000 _parser.py:162(__getitem__)
#         1    0.000    0.000    0.000    0.000 _parser.py:166(__setitem__)
#        22    0.000    0.000    0.000    0.000 _parser.py:170(append)
#       2/1    0.000    0.000    0.000    0.000 _parser.py:172(getwidth)
#         1    0.000    0.000    0.000    0.000 _parser.py:222(__init__)
#        24    0.000    0.000    0.000    0.000 _parser.py:231(__next)
#         3    0.000    0.000    0.000    0.000 _parser.py:247(match)
#        23    0.000    0.000    0.000    0.000 _parser.py:252(get)
#         2    0.000    0.000    0.000    0.000 _parser.py:284(tell)
#         1    0.000    0.000    0.000    0.000 _parser.py:447(_parse_sub)
#         1    0.000    0.000    0.000    0.000 _parser.py:507(_parse)
#         1    0.000    0.000    0.000    0.000 _parser.py:73(__init__)
#         2    0.000    0.000    0.000    0.000 _parser.py:79(groups)
#         1    0.000    0.000    0.000    0.000 _parser.py:954(fix_flags)
#         1    0.000    0.000    0.000    0.000 _parser.py:970(parse)
#        22    0.000    0.000    0.000    0.000 _ufunc_config.py:132(geterr)
#        22    0.000    0.000    0.000    0.000 _ufunc_config.py:33(seterr)
#        11    0.000    0.000    0.000    0.000 _ufunc_config.py:426(__init__)
#        11    0.000    0.000    0.000    0.000 _ufunc_config.py:430(__enter__)
#        11    0.000    0.000    0.000    0.000 _ufunc_config.py:435(__exit__)
#        35    0.000    0.000    0.000    0.000 _validators.py:226(validate_bool_kwarg)
#         1    0.000    0.000    0.000    0.000 accessor.py:178(__get__)
#         1    0.000    0.000    0.032    0.032 accessor.py:79(_getter)
#         1    0.000    0.000    0.000    0.000 accessors.py:482(__new__)
#         1    0.000    0.000    0.000    0.000 accessors.py:53(__init__)
#         1    0.000    0.000    0.000    0.000 accessors.py:64(_get_values)
#         1    0.000    0.000    0.032    0.032 accessors.py:82(_delegate_property_get)
#        14    0.000    0.000    0.000    0.000 algorithms.py:117(_ensure_data)
#        21    0.000    0.000    0.000    0.000 algorithms.py:1264(__init__)
#     21/11    0.001    0.000    0.022    0.002 algorithms.py:1275(nlargest)
#        21    0.000    0.000    0.000    0.000 algorithms.py:1283(is_valid_dtype_n_method)
#        11    0.001    0.000    0.014    0.001 algorithms.py:1310(compute)
#        10    0.000    0.000    0.000    0.000 algorithms.py:1388(__init__)
#        10    0.000    0.000    0.020    0.002 algorithms.py:1397(compute)
#        10    0.000    0.000    0.001    0.000 algorithms.py:1413(get_indexer)
#        43    0.000    0.000    0.003    0.000 algorithms.py:1484(take)
#         3    0.000    0.000    0.031    0.010 algorithms.py:1795(safe_sort)
#         6    0.000    0.000    0.000    0.000 algorithms.py:197(_reconstruct_data)
#         3    0.000    0.000    0.000    0.000 algorithms.py:235(_ensure_arraylike)
#         3    0.000    0.000    0.005    0.002 algorithms.py:269(_get_hashtable_algo)
#         3    0.000    0.000    0.005    0.002 algorithms.py:287(_check_object_for_strings)
#         3    0.000    0.000    0.047    0.016 algorithms.py:530(factorize_array)
#         3    0.001    0.000    0.079    0.026 algorithms.py:593(factorize)
#         3    0.000    0.000    0.000    0.000 algorithms.py:855(resolve_na_sentinel)
#         3    0.000    0.000    0.000    0.000 algorithms.py:905(_re_wrap_factorize)
#        13    0.000    0.000    0.000    0.000 api.py:384(default_index)
#         1    0.000    0.000    0.000    0.000 apply.py:1089(__init__)
#         1    0.003    0.003    0.081    0.081 apply.py:1108(apply)
#         1    0.000    0.000    0.000    0.000 apply.py:112(__init__)
#         1    0.000    0.000    0.078    0.078 apply.py:1159(apply_standard)
#        10    0.000    0.000    0.030    0.003 array_ops.py:231(comparison_op)
#        10    0.000    0.000    0.030    0.003 array_ops.py:60(comp_method_OBJECT_ARRAY)
#        10    0.000    0.000    0.032    0.003 arraylike.py:40(__eq__)
#         1    0.000    0.000    0.003    0.003 astype.py:192(astype_array)
#         1    0.000    0.000    0.003    0.003 astype.py:239(astype_array_safe)
#        32    0.000    0.000    0.000    0.000 base.py:1023(view)
#        41    0.000    0.000    0.001    0.000 base.py:1168(take)
#        41    0.000    0.000    0.000    0.000 base.py:1194(_maybe_disallow_fill)
#         6    0.000    0.000    0.000    0.000 base.py:124(_reset_cache)
#         1    0.000    0.000    0.000    0.000 base.py:1443(format)
#         1    0.000    0.000    0.000    0.000 base.py:1465(_format_with_header)
#        11    0.000    0.000    0.000    0.000 base.py:154(_consolidate_inplace)
#         1    0.000    0.000    0.000    0.000 base.py:161(_freeze)
#         1    0.000    0.000    0.000    0.000 base.py:163(array)
#         3    0.000    0.000    0.000    0.000 base.py:168(__setattr__)
#       165    0.000    0.000    0.000    0.000 base.py:1734(name)
#         1    0.000    0.000    0.000    0.000 base.py:1752(_validate_names)
#         1    0.000    0.000    0.000    0.000 base.py:1785(_get_default_index_names)
#         2    0.000    0.000    0.000    0.000 base.py:1820(_get_names)
#        12    0.000    0.000    0.000    0.000 base.py:1823(_set_names)
#        12    0.000    0.000    0.000    0.000 base.py:1852(set_names)
#         1    0.000    0.000    0.004    0.004 base.py:192(grouped_reduce)
#        12    0.000    0.000    0.000    0.000 base.py:1963(rename)
#         1    0.000    0.000    0.000    0.000 base.py:216(_obj_with_exclusions)
#        11    0.000    0.000    0.000    0.000 base.py:229(construct_from_string)
#         1    0.000    0.000    0.000    0.000 base.py:231(__getitem__)
#         4    0.000    0.000    0.000    0.000 base.py:2381(is_unique)
#        30    0.000    0.000    0.000    0.000 base.py:241(disallow_kwargs)
#        22    0.000    0.000    0.000    0.000 base.py:2421(is_boolean)
#         1    0.000    0.000    0.000    0.000 base.py:2745(inferred_type)
#        17    0.000    0.000    0.000    0.000 base.py:2752(_is_all_dates)
#        20    0.000    0.000    0.000    0.000 base.py:2783(_is_multi)
#        24    0.000    0.000    0.000    0.000 base.py:2801(_na_value)
#        95    0.000    0.000    0.001    0.000 base.py:286(is_dtype)
#        24    0.000    0.000    0.000    0.000 base.py:313(shape)
#        10    0.000    0.000    0.000    0.000 base.py:3209(_validate_sort_keyword)
#       167    0.000    0.000    0.000    0.000 base.py:324(ndim)
#         1    0.000    0.000    0.000    0.000 base.py:340(_is_boolean)
#         1    0.000    0.000    0.000    0.000 base.py:356(size)
#        10    0.000    0.000    0.001    0.000 base.py:3570(difference)
#        10    0.000    0.000    0.000    0.000 base.py:3731(_assert_can_do_setop)
#        10    0.000    0.000    0.000    0.000 base.py:3737(_convert_can_do_setop)
#        40    0.000    0.000    0.002    0.000 base.py:3754(get_loc)
#        22    0.000    0.000    0.001    0.000 base.py:3888(get_indexer)
#        22    0.000    0.000    0.000    0.000 base.py:4020(_check_indexing_method)
#         6    0.000    0.000    0.000    0.000 base.py:413(_engine_type)
#        13    0.000    0.000    0.000    0.000 base.py:4205(_validate_positional_slice)
#     33/30    0.001    0.000    0.003    0.000 base.py:430(__new__)
#        28    0.000    0.000    0.000    0.000 base.py:46(__len__)
#         4    0.000    0.000    0.000    0.000 base.py:494(find)
#       184    0.000    0.000    0.000    0.000 base.py:5090(_values)
#         6    0.000    0.000    0.000    0.000 base.py:5116(_get_engine_target)
#         3    0.000    0.000    0.000    0.000 base.py:5204(_validate_fill_value)
#        57    0.000    0.000    0.000    0.000 base.py:5254(__contains__)
#        85    0.000    0.000    0.000    0.000 base.py:5304(__getitem__)
#        22    0.000    0.000    0.003    0.000 base.py:5377(append)
#        35    0.000    0.000    0.000    0.000 base.py:54(shape)
#        22    0.000    0.000    0.000    0.000 base.py:5402(<setcomp>)
#        21    0.000    0.000    0.002    0.000 base.py:5407(_concat)
#        21    0.000    0.000    0.000    0.000 base.py:5411(<listcomp>)
#         1    0.000    0.000    0.000    0.000 base.py:543(empty)
#        11    0.000    0.000    0.000    0.000 base.py:5464(equals)
#         2    0.000    0.000    0.000    0.000 base.py:555(<genexpr>)
#        94    0.000    0.000    0.000    0.000 base.py:56(<genexpr>)
#        10    0.000    0.000    0.000    0.000 base.py:574(_ensure_array)
#        53    0.000    0.000    0.000    0.000 base.py:58(_validate_set_axis)
#        30    0.000    0.000    0.000    0.000 base.py:588(_dtype_to_subclass)
#         1    0.000    0.000    0.000    0.000 base.py:5921(_check_indexing_error)
#        11    0.000    0.000    0.001    0.000 base.py:6032(get_indexer_for)
#        33    0.000    0.000    0.000    0.000 base.py:6193(_index_as_unique)
#        11    0.000    0.000    0.000    0.000 base.py:6205(_maybe_promote)
#        11    0.000    0.000    0.000    0.000 base.py:6285(_should_compare)
#        11    0.000    0.000    0.000    0.000 base.py:6303(_is_comparable_dtype)
#        40    0.000    0.000    0.000    0.000 base.py:6569(_maybe_cast_indexer)
#        22    0.000    0.000    0.000    0.000 base.py:6576(_maybe_cast_listlike_indexer)
#        39    0.000    0.000    0.000    0.000 base.py:6582(_validate_indexer)
#         1    0.000    0.000    0.000    0.000 base.py:6804(delete)
#         3    0.000    0.000    0.001    0.000 base.py:6844(insert)
#       126    0.000    0.000    0.000    0.000 base.py:690(_simple_new)
#        11    0.000    0.000    0.002    0.000 base.py:6901(drop)
#        29    0.000    0.000    0.004    0.000 base.py:708(_with_infer)
#       110    0.000    0.000    0.001    0.000 base.py:7277(ensure_index)
#        11    0.000    0.000    0.000    0.000 base.py:728(_constructor)
#         1    0.000    0.000    0.000    0.000 base.py:7348(trim_front)
#        13    0.000    0.000    0.000    0.000 base.py:7362(<genexpr>)
#         1    0.000    0.000    0.000    0.000 base.py:7363(<listcomp>)
#        76    0.000    0.000    0.000    0.000 base.py:7372(maybe_extract_name)
#        10    0.000    0.000    0.001    0.000 base.py:7396(_maybe_cast_data_without_dtype)
#         3    0.000    0.000    0.000    0.000 base.py:742(__iter__)
#        11    0.000    0.000    0.000    0.000 base.py:7456(unpack_nested_dtype)
#        30    0.000    0.000    0.000    0.000 base.py:821(_view)
#         2    0.000    0.000    0.000    0.000 base.py:830(_rename)
#        11    0.000    0.000    0.000    0.000 base.py:839(is_)
#       183    0.000    0.000    0.000    0.000 base.py:870(_reset_identity)
#         6    0.000    0.000    0.000    0.000 base.py:881(_engine)
#       181    0.000    0.000    0.000    0.000 base.py:925(__len__)
#        20    0.000    0.000    0.000    0.000 base.py:931(__array__)
#        41    0.000    0.000    0.000    0.000 base.py:986(dtype)
#         8    0.000    0.000    0.000    0.000 blocks.py:160(_consolidate_key)
#        11    0.000    0.000    0.000    0.000 blocks.py:165(_can_hold_na)
#         1    0.000    0.000    0.031    0.031 blocks.py:1920(delete)
#        21    0.000    0.000    0.000    0.000 blocks.py:196(external_values)
#        33    0.000    0.000    0.000    0.000 blocks.py:200(fill_value)
#        48    0.000    0.000    0.000    0.000 blocks.py:2091(maybe_coerce_values)
#        52    0.000    0.000    0.000    0.000 blocks.py:2120(get_block_type)
#        10    0.000    0.000    0.000    0.000 blocks.py:213(mgr_locs)
#         7    0.000    0.000    0.000    0.000 blocks.py:2161(new_block_2d)
#        40    0.000    0.000    0.001    0.000 blocks.py:2172(new_block)
#        40    0.000    0.000    0.000    0.000 blocks.py:2186(check_ndim)
#         1    0.000    0.000    0.000    0.000 blocks.py:221(make_block)
#        37    0.000    0.000    0.000    0.000 blocks.py:2250(extend_blocks)
#         5    0.000    0.000    0.000    0.000 blocks.py:2266(ensure_block_shape)
#        51    0.000    0.000    0.000    0.000 blocks.py:236(make_block_same_class)
#        21    0.000    0.000    0.000    0.000 blocks.py:2370(external_values)
#         1    0.000    0.000    0.000    0.000 blocks.py:275(__len__)
#        77    0.000    0.000    0.000    0.000 blocks.py:500(dtype)
#         1    0.000    0.000    0.003    0.003 blocks.py:504(astype)
#        32    0.000    0.000    0.001    0.000 blocks.py:544(copy)
#         2    0.000    0.000    0.000    0.000 blocks.py:823(shape)
#        37    0.000    0.000    0.000    0.000 blocks.py:827(iget)
#        13    0.000    0.000    0.000    0.000 blocks.py:836(_slice)
#        51    0.000    0.000    0.004    0.000 blocks.py:861(take_nd)
#         4    0.000    0.000    0.000    0.000 cast.py:1004(coerce_indexer_dtype)
#        34    0.000    0.000    0.011    0.000 cast.py:1178(maybe_infer_to_datetimelike)
#        21    0.000    0.000    0.004    0.000 cast.py:1291(maybe_cast_to_datetime)
#        19    0.000    0.000    0.000    0.000 cast.py:1422(sanitize_to_nanoseconds)
#         3    0.000    0.000    0.000    0.000 cast.py:1763(construct_1d_object_array_from_listlike)
#        12    0.000    0.000    0.000    0.000 cast.py:1788(maybe_cast_to_integer_array)
#         3    0.000    0.000    0.000    0.000 cast.py:1931(np_can_hold_element)
#         1    0.000    0.000    0.000    0.000 cast.py:259(maybe_downcast_to_dtype)
#         1    0.000    0.000    0.000    0.000 cast.py:328(maybe_downcast_numeric)
#         1    0.000    0.000    0.000    0.000 cast.py:508(ensure_dtype_can_hold_na)
#        56    0.000    0.000    0.000    0.000 cast.py:527(maybe_promote)
#         3    0.000    0.000    0.000    0.000 cast.py:566(_maybe_promote_cached)
#         3    0.000    0.000    0.000    0.000 cast.py:574(_maybe_promote)
#         1    0.000    0.000    0.000    0.000 cast.py:714(_ensure_dtype_type)
#        10    0.000    0.000    0.000    0.000 common.py:1048(is_numeric_v_string_like)
#        52    0.000    0.000    0.000    0.000 common.py:1154(needs_i8_conversion)
#        45    0.000    0.000    0.000    0.000 common.py:1204(is_numeric_dtype)
#        84    0.000    0.000    0.000    0.000 common.py:1246(is_float_dtype)
#        56    0.000    0.000    0.000    0.000 common.py:1278(is_bool_dtype)
#        68    0.000    0.000    0.000    0.000 common.py:1420(is_1d_only_ea_dtype)
#        30    0.000    0.000    0.000    0.000 common.py:1433(is_extension_array_dtype)
#       215    0.000    0.000    0.000    0.000 common.py:146(classes)
#       215    0.000    0.000    0.000    0.000 common.py:148(<lambda>)
#        66    0.000    0.000    0.000    0.000 common.py:1487(is_ea_or_datetimelike_dtype)
#        23    0.000    0.000    0.000    0.000 common.py:1500(is_complex_dtype)
#        74    0.000    0.000    0.000    0.000 common.py:151(cast_scalar_indexer)
#       208    0.000    0.000    0.000    0.000 common.py:151(classes_and_not_datetimelike)
#         1    0.000    0.000    0.000    0.000 common.py:1532(_is_dtype)
#       250    0.000    0.000    0.000    0.000 common.py:1556(get_dtype)
#       208    0.000    0.000    0.000    0.000 common.py:156(<lambda>)
#       423    0.000    0.000    0.001    0.000 common.py:1591(_is_dtype_type)
#        84    0.000    0.000    0.000    0.000 common.py:162(is_object_dtype)
#       162    0.000    0.000    0.001    0.000 common.py:1725(validate_all_hashable)
#       325    0.000    0.000    0.000    0.000 common.py:1744(<genexpr>)
#        40    0.000    0.000    0.000    0.000 common.py:1751(pandas_dtype)
#        12    0.000    0.000    0.000    0.000 common.py:178(not_none)
#        36    0.000    0.000    0.000    0.000 common.py:182(<genexpr>)
#        11    0.000    0.000    0.000    0.000 common.py:192(all_none)
#         1    0.000    0.000    0.000    0.000 common.py:192(is_sparse)
#        22    0.000    0.000    0.000    0.000 common.py:196(<genexpr>)
#        13    0.000    0.000    0.000    0.000 common.py:235(asarray_tuplesafe)
#         1    0.000    0.000    0.000    0.000 common.py:303(maybe_iterable_to_list)
#        11    0.000    0.000    0.000    0.000 common.py:319(is_datetime64_dtype)
#         6    0.000    0.000    0.000    0.000 common.py:352(is_datetime64tz_dtype)
#        83    0.000    0.000    0.000    0.000 common.py:362(apply_if_callable)
#        31    0.000    0.000    0.000    0.000 common.py:393(is_timedelta64_dtype)
#         4    0.000    0.000    0.000    0.000 common.py:427(is_period_dtype)
#        22    0.000    0.000    0.000    0.000 common.py:463(is_interval_dtype)
#        71    0.000    0.000    0.000    0.000 common.py:501(is_categorical_dtype)
#         1    0.000    0.000    0.000    0.000 common.py:537(is_string_or_object_np_dtype)
#         1    0.000    0.000    0.000    0.000 common.py:544(is_string_dtype)
#         2    0.000    0.000    0.000    0.000 common.py:546(temp_setattr)
#        50    0.000    0.000    0.000    0.000 common.py:566(require_length_match)
#        10    0.000    0.000    0.032    0.003 common.py:57(new_method)
#         1    0.000    0.000    0.000    0.000 common.py:573(condition)
#        96    0.000    0.000    0.000    0.000 common.py:585(is_dtype_equal)
#         1    0.000    0.000    0.000    0.000 common.py:632(fill_missing_names)
#         1    0.000    0.000    0.000    0.000 common.py:648(<listcomp>)
#        93    0.000    0.000    0.000    0.000 common.py:684(is_integer_dtype)
#        40    0.000    0.000    0.000    0.000 common.py:736(is_signed_integer_dtype)
#        20    0.000    0.000    0.000    0.000 common.py:77(get_op_result_name)
#        30    0.000    0.000    0.000    0.000 common.py:790(is_unsigned_integer_dtype)
#        12    0.000    0.000    0.000    0.000 common.py:85(consensus_name_attr)
#         1    0.000    0.000    0.000    0.000 common.py:929(is_datetime64_ns_dtype)
#        21    0.000    0.000    0.000    0.000 common.py:96(is_bool_indexer)
#        10    0.000    0.000    0.000    0.000 common.py:99(_maybe_match_name)
#        33    0.000    0.000    0.000    0.000 concat.py:103(<listcomp>)
#        33    0.000    0.000    0.000    0.000 concat.py:108(<setcomp>)
#        33    0.000    0.000    0.000    0.000 concat.py:109(<setcomp>)
#        66    0.000    0.000    0.000    0.000 concat.py:110(<genexpr>)
#        67    0.000    0.000    0.000    0.000 concat.py:113(<genexpr>)
#        33    0.000    0.000    0.000    0.000 concat.py:116(<setcomp>)
#        67    0.000    0.000    0.000    0.000 concat.py:117(<genexpr>)
#        12    0.000    0.000    0.005    0.000 concat.py:146(concat)
#        12    0.000    0.000    0.003    0.000 concat.py:389(__init__)
#        12    0.000    0.000    0.000    0.000 concat.py:476(<listcomp>)
#        12    0.000    0.000    0.002    0.000 concat.py:565(get_result)
#        12    0.000    0.000    0.000    0.000 concat.py:578(<listcomp>)
#        12    0.000    0.000    0.000    0.000 concat.py:625(_get_result_dim)
#        12    0.000    0.000    0.002    0.000 concat.py:631(_get_new_axes)
#        12    0.000    0.000    0.002    0.000 concat.py:633(<listcomp>)
#        12    0.000    0.000    0.002    0.000 concat.py:648(_get_concat_axis)
#        12    0.000    0.000    0.000    0.000 concat.py:655(<listcomp>)
#        12    0.000    0.000    0.000    0.000 concat.py:701(_maybe_check_integrity)
#        12    0.000    0.000    0.002    0.000 concat.py:708(_concat_indexes)
#        33    0.000    0.000    0.001    0.000 concat.py:71(concat_compat)
#        66    0.000    0.000    0.000    0.000 concat.py:92(is_nonempty)
#        61    0.000    0.000    0.000    0.000 config.py:116(_get_single_key)
#        61    0.000    0.000    0.001    0.000 config.py:134(_get_option)
#        61    0.000    0.000    0.001    0.000 config.py:262(__call__)
#        61    0.000    0.000    0.000    0.000 config.py:579(_select_options)
#        61    0.000    0.000    0.000    0.000 config.py:597(_get_root)
#       122    0.000    0.000    0.000    0.000 config.py:611(_get_deprecated_option)
#        61    0.000    0.000    0.000    0.000 config.py:638(_translate_key)
#        61    0.000    0.000    0.000    0.000 config.py:650(_warn_if_deprecated)
#         1    0.028    0.028    0.257    0.257 construction.py:100(arrays_to_mgr)
#         1    0.000    0.000    0.209    0.209 construction.py:1038(_convert_object_array)
#        21    0.000    0.000    0.209    0.010 construction.py:1054(convert)
#         1    0.000    0.000    0.209    0.209 construction.py:1060(<listcomp>)
#         1    0.000    0.000    0.000    0.000 construction.py:231(mgr_to_mgr)
#        84    0.000    0.000    0.000    0.000 construction.py:399(extract_array)
#        80    0.000    0.000    0.000    0.000 construction.py:461(ensure_wrapped_if_datetimelike)
#        53    0.000    0.000    0.011    0.000 construction.py:493(sanitize_array)
#         1    0.000    0.000    0.596    0.596 construction.py:496(nested_data_to_arrays)
#         1    0.000    0.000    0.000    0.000 construction.py:525(treat_as_nested)
#         1    0.000    0.000    0.003    0.003 construction.py:588(_homogenize)
#        53    0.000    0.000    0.000    0.000 construction.py:676(_sanitize_ndim)
#        52    0.000    0.000    0.000    0.000 construction.py:713(_sanitize_str_dtypes)
#        53    0.000    0.000    0.000    0.000 construction.py:733(_maybe_repeat)
#        52    0.000    0.000    0.010    0.000 construction.py:744(_try_cast)
#         1    0.002    0.002    0.596    0.596 construction.py:790(to_arrays)
#        32    0.000    0.000    0.000    0.000 construction.py:861(is_empty_data)
#         1    0.000    0.000    0.001    0.001 construction.py:881(create_series_with_explicit_dtype)
#         1    0.000    0.000    0.385    0.385 construction.py:921(_list_of_dict_to_arrays)
#    117408    0.104    0.000    0.115    0.000 construction.py:945(<genexpr>)
#         2    0.000    0.000    0.000    0.000 construction.py:946(<genexpr>)
#         1    0.031    0.031    0.031    0.031 construction.py:952(<listcomp>)
#         1    0.000    0.000    0.209    0.209 construction.py:958(_finalize_columns_and_data)
#         1    0.000    0.000    0.000    0.000 construction.py:980(_validate_or_indexify_columns)
#         2    0.000    0.000    0.000    0.000 contextlib.py:104(__init__)
#         2    0.000    0.000    0.000    0.000 contextlib.py:132(__enter__)
#         2    0.000    0.000    0.000    0.000 contextlib.py:141(__exit__)
#         2    0.000    0.000    0.000    0.000 contextlib.py:287(helper)
#         1    0.000    0.000    0.001    0.001 cp437.py:1(<module>)
#         2    0.000    0.000    0.000    0.000 cp437.py:14(decode)
#         1    0.000    0.000    0.000    0.000 cp437.py:17(IncrementalEncoder)
#         1    0.000    0.000    0.000    0.000 cp437.py:21(IncrementalDecoder)
#         1    0.000    0.000    0.000    0.000 cp437.py:25(StreamWriter)
#         1    0.000    0.000    0.000    0.000 cp437.py:28(StreamReader)
#         1    0.000    0.000    0.000    0.000 cp437.py:33(getregentry)
#         1    0.000    0.000    0.000    0.000 cp437.py:9(Codec)
#         1    0.000    0.000    0.000    0.000 dataclasses.py:1256(is_dataclass)
#         1    0.000    0.000    0.000    0.000 datetimelike.py:1939(__init__)
#         1    0.000    0.000    0.000    0.000 datetimelike.py:2012(_reso)
#         1    0.000    0.000    0.000    0.000 datetimelike.py:2138(ensure_arraylike_for_datetimelike)
#         1    0.000    0.000    0.000    0.000 datetimelike.py:2206(validate_inferred_freq)
#         1    0.000    0.000    0.000    0.000 datetimelike.py:2243(maybe_infer_freq)
#         1    0.000    0.000    0.000    0.000 datetimelike.py:295(asi8)
#         2    0.000    0.000    0.000    0.000 datetimelike.py:347(__getitem__)
#         2    0.000    0.000    0.000    0.000 datetimelike.py:368(_get_getitem_freq)
#         2    0.000    0.000    0.000    0.000 datetimelike.py:560(copy)
#         5    0.000    0.000    0.000    0.000 datetimelike.py:926(freq)
#         1    0.000    0.000    0.028    0.028 datetimes.py:1285(date)
#         1    0.000    0.000    0.000    0.000 datetimes.py:134(should_cache)
#         1    0.000    0.000    0.001    0.001 datetimes.py:194(_maybe_cache)
#         1    0.000    0.000    0.000    0.000 datetimes.py:1980(_sequence_to_dt64ns)
#         1    0.000    0.000    0.176    0.176 datetimes.py:2129(objects_to_datetime64ns)
#         2    0.000    0.000    0.000    0.000 datetimes.py:2215(maybe_convert_dtype)
#         1    0.000    0.000    0.000    0.000 datetimes.py:2284(_maybe_infer_tz)
#         3    0.000    0.000    0.000    0.000 datetimes.py:2314(_validate_dt64_dtype)
#         2    0.000    0.000    0.000    0.000 datetimes.py:2366(validate_tz_from_dtype)
#         1    0.000    0.000    0.000    0.000 datetimes.py:257(_validate_dtype)
#         1    0.000    0.000    0.000    0.000 datetimes.py:265(_simple_new)
#         1    0.000    0.000    0.000    0.000 datetimes.py:290(_from_sequence_not_strict)
#         1    0.000    0.000    0.000    0.000 datetimes.py:313(__new__)
#         1    0.000    0.000    0.176    0.176 datetimes.py:325(_convert_listlike_datetimes)
#        22    0.000    0.000    0.000    0.000 datetimes.py:495(dtype)
#         3    0.000    0.000    0.000    0.000 datetimes.py:520(tz)
#         1    0.000    0.000    0.178    0.178 datetimes.py:705(to_datetime)
#         1    0.000    0.000    0.000    0.000 datetimes.py:739(_local_timestamps)
#         2    0.000    0.000    0.000    0.000 datetimes.py:94(tz_to_dtype)
#    117407    0.253    0.000    5.402    0.000 decoder.py:332(decode)
#    117407    4.951    0.000    4.951    0.000 decoder.py:343(raw_decode)
#        10    0.000    0.000    0.000    0.000 dispatch.py:13(should_extension_dispatch)
#         1    0.000    0.000    0.000    0.000 dtype.py:125(construct_from_string)
#         1    0.000    0.000    0.000    0.000 dtype.py:216(construct_from_string)
#         1    0.000    0.000    0.000    0.000 dtypes.py:1185(construct_from_string)
#        22    0.000    0.000    0.000    0.000 dtypes.py:1247(is_dtype)
#         1    0.000    0.000    0.000    0.000 dtypes.py:303(construct_from_string)
#         3    0.000    0.000    0.000    0.000 dtypes.py:682(__init__)
#         1    0.000    0.000    0.000    0.000 dtypes.py:714(_reso)
#         1    0.000    0.000    0.000    0.000 dtypes.py:727(unit)
#         6    0.000    0.000    0.000    0.000 dtypes.py:734(tz)
#         1    0.000    0.000    0.000    0.000 dtypes.py:754(construct_from_string)
#         1    0.000    0.000    0.000    0.000 dtypes.py:790(__str__)
#         1    0.000    0.000    0.000    0.000 dtypes.py:793(name)
#         1    0.000    0.000    0.000    0.000 dtypes.py:803(__eq__)
#         1    0.000    0.000    0.000    0.000 dtypes.py:913(construct_from_string)
#         1    0.000    0.000    0.000    0.000 dtypes.py:977(is_dtype)
#         2    0.000    0.000    0.000    0.000 enum.py:1091(__new__)
#        30    0.000    0.000    0.000    0.000 enum.py:1243(value)
#         2    0.000    0.000    0.000    0.000 enum.py:1515(__and__)
#        30    0.000    0.000    0.000    0.000 enum.py:192(__get__)
#         2    0.000    0.000    0.000    0.000 enum.py:685(__call__)
#         2    0.000    0.000    0.028    0.014 extension.py:70(fget)
#       149    0.000    0.000    0.000    0.000 flags.py:49(__init__)
#       153    0.000    0.000    0.000    0.000 flags.py:53(allows_duplicate_labels)
#       141    0.000    0.000    0.000    0.000 flags.py:85(allows_duplicate_labels)
#         2    0.000    0.000    0.001    0.000 format.py:1252(format_array)
#         2    0.000    0.000    0.000    0.000 format.py:1332(__init__)
#         2    0.000    0.000    0.001    0.000 format.py:1358(get_result)
#         1    0.000    0.000    0.000    0.000 format.py:1362(_format_strings)
#        10    0.000    0.000    0.000    0.000 format.py:1383(_format)
#         1    0.000    0.000    0.000    0.000 format.py:1610(_format_strings)
#        10    0.000    0.000    0.000    0.000 format.py:1614(<lambda>)
#         1    0.000    0.000    0.000    0.000 format.py:1616(<listcomp>)
#         2    0.000    0.000    0.000    0.000 format.py:1904(_make_fixed_width)
#        22    0.000    0.000    0.000    0.000 format.py:1919(<genexpr>)
#        20    0.000    0.000    0.000    0.000 format.py:1928(just)
#         2    0.000    0.000    0.000    0.000 format.py:1934(<listcomp>)
#         1    0.000    0.000    0.001    0.001 format.py:269(__init__)
#         1    0.000    0.000    0.001    0.001 format.py:301(_chk_truncate)
#         1    0.000    0.000    0.000    0.000 format.py:328(_get_footer)
#         1    0.000    0.000    0.000    0.000 format.py:369(_get_formatted_index)
#         1    0.000    0.000    0.000    0.000 format.py:380(_get_formatted_values)
#         1    0.000    0.000    0.001    0.001 format.py:389(to_string)
#         3    0.000    0.000    0.000    0.000 format.py:429(__init__)
#        52    0.000    0.000    0.000    0.000 format.py:432(len)
#         5    0.000    0.000    0.000    0.000 format.py:435(justify)
#         1    0.000    0.000    0.000    0.000 format.py:438(adjoin)
#         3    0.000    0.000    0.000    0.000 format.py:481(get_adjustment)
#         1    0.000    0.000    0.000    0.000 format.py:522(get_series_repr_params)
#         2    0.000    0.000    0.003    0.001 frame.py:12012(_reindex_for_setitem)
#        13    0.000    0.000    0.000    0.000 frame.py:1498(__len__)
#        37    0.000    0.000    0.002    0.000 frame.py:3703(_ixs)
#        57    0.000    0.000    0.013    0.000 frame.py:3758(__getitem__)
#        10    0.000    0.000    0.009    0.001 frame.py:3832(_getitem_bool_array)
#         2    0.000    0.000    0.062    0.031 frame.py:3955(__setitem__)
#         1    0.000    0.000    0.058    0.058 frame.py:4132(_iset_item_mgr)
#         2    0.000    0.000    0.059    0.029 frame.py:4139(_set_item_mgr)
#         2    0.000    0.000    0.062    0.031 frame.py:4164(_set_item)
#         4    0.000    0.000    0.000    0.000 frame.py:4234(_ensure_valid_index)
#        37    0.000    0.000    0.001    0.000 frame.py:4257(_box_col_values)
#        34    0.000    0.000    0.027    0.001 frame.py:4271(_clear_item_cache)
#        47    0.000    0.000    0.002    0.000 frame.py:4274(_get_item_cache)
#         2    0.000    0.000    0.004    0.002 frame.py:4756(insert)
#         4    0.000    0.000    0.006    0.001 frame.py:4892(_sanitize_column)
#        31    0.000    0.000    0.000    0.000 frame.py:600(_constructor)
#        33    0.000    0.000    0.853    0.026 frame.py:609(__init__)
#        11    0.001    0.000    0.009    0.001 frame.py:6128(reset_index)
#        10    0.000    0.000    0.021    0.002 frame.py:7233(nlargest)
#         2    0.000    0.000    0.003    0.001 frame.py:8267(groupby)
#         3    0.000    0.000    0.000    0.000 frame.py:857(axes)
#         3    0.000    0.000    0.000    0.000 fromnumeric.py:1034(_argsort_dispatcher)
#         3    0.000    0.000    0.000    0.000 fromnumeric.py:1038(argsort)
#         6    0.000    0.000    0.000    0.000 fromnumeric.py:1777(_ravel_dispatcher)
#         6    0.000    0.000    0.000    0.000 fromnumeric.py:1781(ravel)
#        11    0.000    0.000    0.000    0.000 fromnumeric.py:1888(_nonzero_dispatcher)
#        11    0.000    0.000    0.000    0.000 fromnumeric.py:1892(nonzero)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2427(_all_dispatcher)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2432(all)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2950(_prod_dispatcher)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2955(prod)
#        14    0.000    0.000    0.000    0.000 fromnumeric.py:51(_wrapfunc)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:69(_wrapreduction)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:70(<dictcomp>)
#        13    0.000    0.000    0.000    0.000 frozen.py:70(__getitem__)
#        21    0.000    0.000    0.000    0.000 function.py:56(__call__)
#         3    0.000    0.000    0.000    0.000 function_base.py:5050(_delete_dispatcher)
#         3    0.027    0.009    0.031    0.010 function_base.py:5054(delete)
#         3    0.000    0.000    0.000    0.000 function_base.py:5246(_insert_dispatcher)
#         3    0.000    0.000    0.000    0.000 function_base.py:5250(insert)
#         6    0.000    0.000    0.000    0.000 function_base.py:5440(_append_dispatcher)
#         6    0.000    0.000    0.000    0.000 function_base.py:5444(append)
#         1    0.000    0.000    0.000    0.000 generic.py:1402(__getitem__)
#         1    0.000    0.000    0.000    0.000 generic.py:1418(_gotitem)
#         2    0.000    0.000    0.000    0.000 generic.py:1754(_check_label_or_level_ambiguity)
#         2    0.000    0.000    0.000    0.000 generic.py:1775(<genexpr>)
#         1    0.000    0.000    0.000    0.000 generic.py:179(_wrap_agged_manager)
#         1    0.000    0.000    0.000    0.000 generic.py:190(_get_data_to_aggregate)
#         4    0.000    0.000    0.000    0.000 generic.py:1997(__contains__)
#       149    0.001    0.000    0.001    0.000 generic.py:259(__init__)
#       153    0.000    0.000    0.000    0.000 generic.py:332(attrs)
#       294    0.000    0.000    0.000    0.000 generic.py:353(flags)
#        10    0.000    0.000    0.002    0.000 generic.py:3778(take)
#        20    0.000    0.000    0.010    0.000 generic.py:3873(_take)
#        10    0.000    0.000    0.008    0.001 generic.py:3894(_take_with_is_copy)
#      1152    0.001    0.000    0.001    0.000 generic.py:40(_check)
#        10    0.000    0.000    0.000    0.000 generic.py:4114(_set_is_copy)
#         2    0.000    0.000    0.000    0.000 generic.py:4137(_check_setitem_copy)
#        11    0.000    0.000    0.000    0.000 generic.py:4255(_check_inplace_and_allows_duplicate_labels)
#        15    0.000    0.000    0.000    0.000 generic.py:445(_validate_dtype)
#        11    0.000    0.000    0.004    0.000 generic.py:4475(drop)
#      1152    0.001    0.000    0.001    0.000 generic.py:45(_instancecheck)
#        11    0.000    0.000    0.004    0.000 generic.py:4512(_drop_axis)
#       118    0.000    0.000    0.000    0.000 generic.py:550(_get_axis_number)
#        11    0.000    0.000    0.000    0.000 generic.py:558(_get_axis_name)
#        46    0.000    0.000    0.000    0.000 generic.py:564(_get_axis)
#        20    0.000    0.000    0.000    0.000 generic.py:570(_get_block_manager_axis)
#       141    0.001    0.000    0.002    0.000 generic.py:5844(__finalize__)
#        24    0.000    0.000    0.000    0.000 generic.py:5876(<genexpr>)
#        36    0.000    0.000    0.000    0.000 generic.py:5881(<genexpr>)
#        88    0.000    0.000    0.000    0.000 generic.py:5888(__getattr__)
#       216    0.001    0.000    0.002    0.000 generic.py:5904(__setattr__)
#        20    0.000    0.000    0.004    0.000 generic.py:5959(_protect_consolidate)
#        20    0.000    0.000    0.004    0.000 generic.py:5973(_consolidate_inplace)
#        20    0.000    0.000    0.004    0.000 generic.py:5977(f)
#         1    0.000    0.000    0.003    0.003 generic.py:6076(astype)
#        22    0.000    0.000    0.003    0.000 generic.py:6258(copy)
#         7    0.000    0.000    0.000    0.000 generic.py:640(_info_axis)
#         1    0.000    0.000    0.000    0.000 generic.py:664(ndim)
#        21    0.000    0.000    0.000    0.000 generic.py:821(_set_axis)
#         1    0.000    0.000    0.000    0.000 groupby.py:1065(_set_group_selection)
#         1    0.000    0.000    0.000    0.000 groupby.py:1092(_reset_group_selection)
#         2    0.000    0.000    0.000    0.000 groupby.py:1105(_group_selection_context)
#         1    0.000    0.000    0.000    0.000 groupby.py:1321(_resolve_numeric_only)
#         1    0.000    0.000    0.004    0.004 groupby.py:1699(_agg_general)
#         1    0.000    0.000    0.004    0.004 groupby.py:1759(_cython_agg_general)
#         1    0.000    0.000    0.004    0.004 groupby.py:1789(array_func)
#         1    0.000    0.000    0.000    0.000 groupby.py:1961(_obj_1d_constructor)
#         1    0.000    0.000    0.090    0.090 groupby.py:2407(size)
#         1    0.000    0.000    0.004    0.004 groupby.py:2435(sum)
#         3    0.000    0.000    0.000    0.000 groupby.py:4116(_reindex_output)
#         3    0.000    0.000    0.000    0.000 groupby.py:4158(<genexpr>)
#         3    0.000    0.000    0.003    0.001 groupby.py:922(__init__)
#         1    0.000    0.000    0.000    0.000 groupby.py:981(__getattr__)
#         3    0.000    0.000    0.000    0.000 grouper.py:467(__init__)
#         3    0.000    0.000    0.000    0.000 grouper.py:569(name)
#         3    0.000    0.000    0.000    0.000 grouper.py:587(_ilevel)
#         4    0.000    0.000    0.000    0.000 grouper.py:602(ngroups)
#         5    0.000    0.000    0.079    0.016 grouper.py:615(codes)
#         3    0.000    0.000    0.000    0.000 grouper.py:639(result_index)
#         3    0.000    0.000    0.001    0.000 grouper.py:649(group_index)
# ...
#         1    0.000    0.000    0.000    0.000 zipfile.py:820(__init__)
#    117408    0.161    0.000    6.217    0.000 zipfile.py:896(readline)
#    770397    0.763    0.000    3.478    0.000 zipfile.py:912(peek)
#    877277    1.073    0.000    3.501    0.000 zipfile.py:930(read)
#    106879    0.068    0.000    0.235    0.000 zipfile.py:965(_update_crc)
#       184    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x00007FFF7712A4B0}
#        28    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#     73/10    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         2    0.000    0.000    0.000    0.000 {built-in method _codecs.charmap_decode}
#         1    0.000    0.000    0.000    0.000 {built-in method _imp._fix_co_filename}
#         6    0.000    0.000    0.000    0.000 {built-in method _imp.acquire_lock}
#         1    0.000    0.000    0.000    0.000 {built-in method _imp.find_frozen}
#         1    0.000    0.000    0.000    0.000 {built-in method _imp.is_builtin}
#         6    0.000    0.000    0.000    0.000 {built-in method _imp.release_lock}
#         6    0.000    0.000    0.000    0.000 {built-in method _operator.index}
#         1    0.000    0.000    0.000    0.000 {built-in method _simple_new}
#         1    0.000    0.000    0.000    0.000 {built-in method _sre.compile}
#        21    0.000    0.000    0.000    0.000 {built-in method _sre.unicode_iscased}
#        19    0.000    0.000    0.000    0.000 {built-in method _sre.unicode_tolower}
#         7    0.000    0.000    0.000    0.000 {built-in method _struct.unpack}
#         2    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         2    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#       120    0.000    0.000    0.000    0.000 {built-in method _warnings._filters_mutated}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.__build_class__}
#         1    0.000    0.000    0.004    0.004 {built-in method builtins.__import__}
#       234    0.000    0.000    0.001    0.000 {built-in method builtins.all}
#       109    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#       119    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.chr}
#         1    0.000    0.000    0.001    0.001 {built-in method builtins.exec}
# 1534/1531    0.000    0.000    0.029    0.000 {built-in method builtins.getattr}
#       305    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#       362    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
# 123744/123636    0.019    0.000    0.021    0.000 {built-in method builtins.isinstance}
#       867    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#        12    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
# 2544698/2544218    0.244    0.000    0.244    0.000 {built-in method builtins.len}
#    121633    0.069    0.000    0.069    0.000 {built-in method builtins.max}
#     14763    0.004    0.000    0.004    0.000 {built-in method builtins.min}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#        21    0.000    0.000    0.000    0.000 {built-in method builtins.ord}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.setattr}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.sorted}
#        27    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#         3    0.000    0.000    0.000    0.000 {built-in method from_bytes}
#         1    0.001    0.001    0.001    0.001 {built-in method io.open_code}
#         1    0.001    0.001    0.001    0.001 {built-in method io.open}
#         1    0.000    0.000    0.000    0.000 {built-in method marshal.loads}
#         1    0.000    0.000    0.000    0.000 {built-in method nt._path_splitroot}
#         3    0.000    0.000    0.000    0.000 {built-in method nt.fspath}
#         1    0.000    0.000    0.000    0.000 {built-in method nt.get_terminal_size}
#         2    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#         3    0.001    0.000    0.001    0.000 {built-in method nt.stat}
#        38    0.000    0.000    0.000    0.000 {built-in method numpy.arange}
#        68    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#        39    0.000    0.000    0.000    0.000 {built-in method numpy.asanyarray}
#   361/351    0.000    0.000    0.000    0.000 {built-in method numpy.asarray}
#   165/143    0.036    0.000    0.067    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#         8    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#       116    0.011    0.000    0.011    0.000 {built-in method numpy.empty}
#        44    0.000    0.000    0.000    0.000 {built-in method numpy.geterrobj}
#        22    0.000    0.000    0.000    0.000 {built-in method numpy.seterrobj}
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.zeros}
#         3    0.000    0.000    0.000    0.000 {built-in method pandas._libs.lib.is_datetime_array}
#        28    0.000    0.000    0.000    0.000 {built-in method pandas._libs.missing.checknull}
#         1    0.000    0.000    0.000    0.000 {built-in method pandas._libs.missing.isnaobj}
#         1    0.159    0.159    0.176    0.176 {built-in method pandas._libs.tslib.array_to_datetime}
#         1    0.000    0.000    0.000    0.000 {built-in method pandas._libs.tslibs.offsets.to_offset}
#         1    0.000    0.000    0.000    0.000 {built-in method pandas._libs.tslibs.timezones.is_utc}
#         5    0.000    0.000    0.000    0.000 {built-in method pandas._libs.tslibs.timezones.maybe_get_tz}
#         2    0.000    0.000    0.000    0.000 {built-in method time.time}
#    106880    0.167    0.000    0.167    0.000 {built-in method zlib.crc32}
#         1    0.000    0.000    0.000    0.000 {built-in method zlib.decompressobj}
#         2    0.000    0.000    0.000    0.000 {function DatetimeLikeArrayMixin.copy at 0x000001FF09B45300}
#        13    0.000    0.000    0.000    0.000 {function FrozenList.__getitem__ at 0x000001FF09C1E3E0}
#         1    0.000    0.000    0.000    0.000 {function ZipExtFile.close at 0x000001FF059B74C0}
#     89143    1.637    0.000    5.993    0.000 {function ZipExtFile.readline at 0x000001FF059B6FC0}
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of '_io._IOBase' objects}
#     14751    0.004    0.000    0.004    0.000 {method '__exit__' of '_thread.RLock' objects}
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 {method '_from_backing_data' of 'pandas._libs.arrays.NDArrayBacked' objects}
#         3    0.000    0.000    0.000    0.000 {method '_rebuild_blknos_and_blklocs' of 'pandas._libs.internals.BlockManager' objects}
#         1    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#        26    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#        22    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.ndarray' objects}
#        84    0.000    0.000    0.001    0.000 {method 'any' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#       226    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'pandas._libs.internals.BlockPlacement' objects}
#        21    0.031    0.001    0.031    0.001 {method 'argsort' of 'numpy.ndarray' objects}
#        23    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'center' of 'str' objects}
#        40    0.027    0.001    0.027    0.001 {method 'clear' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'close' of '_io.BufferedReader' objects}
#         1    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#       108    0.008    0.000    0.008    0.000 {method 'copy' of 'numpy.ndarray' objects}
#    117409    0.110    0.000    0.115    0.000 {method 'decode' of 'bytes' objects}
#    106879    1.368    0.000    1.368    0.000 {method 'decompress' of 'zlib.Decompress' objects}
#         1    0.000    0.000    0.000    0.000 {method 'delete' of 'pandas._libs.internals.BlockPlacement' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#    234814    0.030    0.000    0.030    0.000 {method 'end' of 're.Match' objects}
#        26    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         2    0.011    0.006    0.011    0.006 {method 'factorize' of 'pandas._libs.hashtable.PyObjectHashTable' objects}
#         1    0.030    0.030    0.030    0.030 {method 'factorize' of 'pandas._libs.hashtable.StringHashTable' objects}
#         1    0.000    0.000    0.000    0.000 {method 'fileno' of '_io.TextIOWrapper' objects}
#    117408    0.063    0.000    0.063    0.000 {method 'find' of 'bytes' objects}
#         1    0.000    0.000    0.000    0.000 {method 'find' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'flush' of 'zlib.Decompress' objects}
#        18    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#        59    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.004    0.004    0.004    0.004 {method 'get_labels_groupby' of 'pandas._libs.hashtable.Int64HashTable' objects}
#        40    0.000    0.000    0.002    0.000 {method 'get_loc' of 'pandas._libs.index.IndexEngine' objects}
#         3    0.000    0.000    0.000    0.000 {method 'increment_above' of 'pandas._libs.internals.BlockPlacement' objects}
#        45    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#         5    0.000    0.000    0.000    0.000 {method 'isalnum' of 'str' objects}
#         5    0.000    0.000    0.000    0.000 {method 'isascii' of 'str' objects}
#         5    0.000    0.000    0.000    0.000 {method 'item' of 'numpy.ndarray' objects}
#        14    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#        21    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#    117407    0.011    0.000    0.011    0.000 {method 'keys' of 'dict' objects}
#        32    0.000    0.000    0.000    0.000 {method 'ljust' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#    234815    0.150    0.000    0.150    0.000 {method 'match' of 're.Pattern' objects}
#         2    0.000    0.000    0.000    0.000 {method 'max' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'min' of 'numpy.ndarray' objects}
#        24    0.000    0.000    0.000    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#         1    0.001    0.001    0.001    0.001 {method 'put' of 'numpy.ndarray' objects}
#        17    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#     14753    0.092    0.000    0.092    0.000 {method 'read' of '_io.BufferedReader' objects}
#         4    0.000    0.000    0.000    0.000 {method 'read' of '_io.BytesIO' objects}
#       112    0.001    0.000    0.001    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#        40    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#        35    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#        15    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'reshape' of 'pandas._libs.arrays.NDArrayBacked' objects}
#         4    0.000    0.000    0.000    0.000 {method 'rfind' of 'str' objects}
#        10    0.000    0.000    0.000    0.000 {method 'rjust' of 'str' objects}
#         6    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#        17    0.000    0.000    0.000    0.000 {method 'rstrip' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'search' of 're.Pattern' objects}
#     14753    0.008    0.000    0.008    0.000 {method 'seek' of '_io.BufferedReader' objects}
#         1    0.000    0.000    0.000    0.000 {method 'seekable' of '_io.BufferedReader' objects}
#        61    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#    117431    0.040    0.000    0.040    0.000 {method 'startswith' of 'str' objects}
#        57    0.002    0.000    0.002    0.000 {method 'take' of 'numpy.ndarray' objects}
#     14750    0.024    0.000    0.024    0.000 {method 'tell' of '_io.BufferedReader' objects}
#         3    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#         7    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         7    0.000    0.000    0.000    0.000 {method 'view' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#         2    0.000    0.000    0.000    0.000 {pandas._libs.algos.ensure_int16}
#         6    0.000    0.000    0.000    0.000 {pandas._libs.algos.ensure_int64}
#         2    0.000    0.000    0.000    0.000 {pandas._libs.algos.ensure_int8}
#        41    0.000    0.000    0.000    0.000 {pandas._libs.algos.ensure_object}
#       130    0.000    0.000    0.000    0.000 {pandas._libs.algos.ensure_platform_int}
#        14    0.001    0.000    0.001    0.000 {pandas._libs.algos.take_1d_int64_int64}
#         2    0.002    0.001    0.002    0.001 {pandas._libs.algos.take_1d_object_object}
#        20    0.000    0.000    0.000    0.000 {pandas._libs.algos.take_2d_axis0_int64_int64}
#        20    0.002    0.000    0.002    0.000 {pandas._libs.algos.take_2d_axis1_object_object}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.internals.get_blkno_placements}
#         1    0.165    0.165    0.165    0.165 {pandas._libs.lib.dicts_to_array}
#         1    0.073    0.073    0.188    0.188 {pandas._libs.lib.fast_unique_multiple_list_gen}
#        34    0.011    0.000    0.011    0.000 {pandas._libs.lib.infer_datetimelike_array}
#         7    0.006    0.001    0.006    0.001 {pandas._libs.lib.infer_dtype}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_all_arraylike}
#        48    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_bool}
#        86    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_float}
#       112    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_integer}
#        62    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_iterator}
#       313    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_list_like}
#       118    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_scalar}
#        80    0.000    0.000    0.000    0.000 {pandas._libs.lib.item_from_zerodim}
#         2    0.045    0.022    0.075    0.037 {pandas._libs.lib.map_infer}
#        42    0.206    0.005    0.207    0.005 {pandas._libs.lib.maybe_convert_objects}
#        10    0.000    0.000    0.000    0.000 {pandas._libs.lib.maybe_indices_to_slice}
#        10    0.030    0.003    0.030    0.003 {pandas._libs.ops.scalar_compare}
#         2    0.000    0.000    0.000    0.000 {pandas._libs.tslibs.np_datetime.py_get_unit_from_dtype}
#         4    0.000    0.000    0.000    0.000 {pandas._libs.tslibs.timezones.tz_standardize}
#         1    0.028    0.028    0.028    0.028 {pandas._libs.tslibs.vectorized.ints_to_pydatetime}

# %%
# =============================================================================
# Cargamos el modulo donde ejecutaremos las funciones de memoria
# =============================================================================
import modulo_funciones_latam #modulo creado para obtener los output de memoria

# =============================================================================
# Ejercicio 1: Función enfocada a la memoria
# =============================================================================

@profile
def q1_memory(file_path: str) -> List[Tuple[str, int]]:
    # Lista para almacenar los datos JSON
    data = []

    # Abre el archivo ZIP
    with zipfile.ZipFile(file_path, 'r') as zip_file:
        with zip_file.open('farmers-protest-tweets-2021-2-4.json') as json_file:
            data = [json.loads(line.decode('utf-8')) for line in json_file]    

    
    # Convierte la lista de datos en un DataFrame de Pandas
    df = pd.DataFrame(data)  
    
    # Agrupar por fecha y contar el número de tweets por fecha y usuario
    df['date'] = pd.to_datetime(df['date'])
    df['username'] = df['user'].apply(lambda x: x['username'])
    grouped = df.groupby([df['date'].dt.date, 'username']).size().reset_index(name='count')
    
    # Obtener las 10 fechas con más tweets
    top_dates = grouped.groupby('date')['count'].sum().nlargest(10).index
    
    # Obtener el usuario con más publicaciones para cada fecha
    result = []
    for date in top_dates:
        top_user = grouped[grouped['date'] == date].nlargest(1, 'count')
        result.append((date, top_user['username'].values[0]))
    return result

# %%
# =============================================================================
# Resultados: Ejercicio 1 (memoria)
# =============================================================================
modulo_funciones_latam.q1_memory(file_path)
# Out:
# Filename: C:\Users\bastian\modulo_funciones_latam.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#     17    167.6 MiB    167.6 MiB           1   @profile
#     18                                         def q1_memory(file_path: str) -> List[Tuple[str, int]]:
#     19                                             # Lista para almacenar los datos JSON
#     20    167.6 MiB      0.0 MiB           1       data = []
#     21
#     22                                             # Abre el archivo ZIP
#     23   1171.9 MiB      0.0 MiB           2       with zipfile.ZipFile(file_path, 'r') as zip_file:
#     24   1171.9 MiB      0.0 MiB           2           with zip_file.open('farmers-protest-tweets-2021-2-4.json') as json_file:
#     25   1171.9 MiB   1003.4 MiB      117410               data = [json.loads(line.decode('utf-8')) for line in json_file]
#     26
#     27
#     28                                             # Convierte la lista de datos en un DataFrame de Pandas
#     29   1195.4 MiB     23.4 MiB           1       df = pd.DataFrame(data)
#     30
#     31                                             # Agrupar por fecha y contar el número de tweets por fecha y usuario
#     32   1194.5 MiB     -0.9 MiB           1       df['date'] = pd.to_datetime(df['date'])
#     33   1195.5 MiB      1.0 MiB      234815       df['username'] = df['user'].apply(lambda x: x['username'])
#     34   1201.0 MiB      5.5 MiB           1       grouped = df.groupby([df['date'].dt.date, 'username']).size().reset_index(name='count')
#     35
#     36                                             # Obtener las 10 fechas con más tweets
#     37   1201.0 MiB      0.0 MiB           1       top_dates = grouped.groupby('date')['count'].sum().nlargest(10).index
#     38
#     39                                             # Obtener el usuario con más publicaciones para cada fecha
#     40   1201.0 MiB      0.0 MiB           1       result = []
#     41   1201.2 MiB      0.0 MiB          11       for date in top_dates:
#     42   1201.2 MiB      0.2 MiB          10           top_user = grouped[grouped['date'] == date].nlargest(1, 'count')
#     43   1201.2 MiB      0.0 MiB          10           result.append((date, top_user['username'].values[0]))
#     44   1201.2 MiB      0.0 MiB           1       return result
# [(datetime.date(2021, 2, 12), 'RanbirS00614606'),
#  (datetime.date(2021, 2, 13), 'MaanDee08215437'),
#  (datetime.date(2021, 2, 17), 'RaaJVinderkaur'),
#  (datetime.date(2021, 2, 16), 'jot__b'),
#  (datetime.date(2021, 2, 14), 'rebelpacifist'),
#  (datetime.date(2021, 2, 18), 'neetuanjle_nitu'),
#  (datetime.date(2021, 2, 15), 'jot__b'),
#  (datetime.date(2021, 2, 20), 'MangalJ23056160'),
#  (datetime.date(2021, 2, 23), 'Surrypuria'),
#  (datetime.date(2021, 2, 19), 'Preetm91')]

# %% [markdown]
# # Ejercicio 2: Los top 10 emojis más usados con su respectivo conteo.

# %%
# =============================================================================
# Ejercicio 2: Función enfocada a extraer los emojis
# =============================================================================

def extract_emojis(text):
    emojis = set()
    for c in text:
        if c in emoji.EMOJI_DATA:
            emojis.add(c)
    return ''.join(emojis)

# %%
# =============================================================================
# Ejercicio 2: Función enfocada al tiempo
# =============================================================================

def q2_time(file_path: str) -> List[Tuple[str, int]]:
    # Lista para almacenar los emojis
    
    start_time = time.time()  # Iniciar la medición de tiempo
    emoji_counts = Counter()
    
    # Abre el archivo ZIP
    with zipfile.ZipFile(file_path, 'r') as zip_file:
        with zip_file.open('farmers-protest-tweets-2021-2-4.json') as json_file:
            for line in json_file:
                tweet = json.loads(line.decode('utf-8'))
                tweet_text = tweet.get('content', '')
                emojis = extract_emojis(tweet_text)
                emoji_counts.update(emojis)
    
    # Obtener los 10 emojis más usados
    top_emojis = emoji_counts.most_common(10)
    end_time = time.time()  # Finalizar la medición de tiempo
    print(f"Tiempo de ejecución: {end_time - start_time} segundos")

    return top_emojis

# %%
# =============================================================================
# Resultados: Ejercicio 2 (tiempo)
# =============================================================================
if __name__ == "__main__":
    profiler = cProfile.Profile()
    result = profiler.runcall(q2_time, file_path)
    print(result)
    print("\n")
    profiler.print_stats()
# Out:
# Tiempo de ejecución: 11.879782915115356 segundos
# [('🙏', 4529), ('✊', 1724), ('❤', 1471), ('😂', 1387), ('🌾', 1377), ('🚜', 1334), ('🏻', 1010), ('🏽', 938), ('🤣', 759), ('👇', 712)]
#
#
#          7340558 function calls in 11.880 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    117407    2.093    0.000    2.153    0.000 1120884137.py:5(extract_emojis)
#         1    0.561    0.561   11.880   11.880 2312491106.py:5(q2_time)
#    117408    0.045    0.000    0.097    0.000 <frozen abc>:117(__instancecheck__)
#    117407    0.159    0.000    3.796    0.000 __init__.py:299(loads)
#         1    0.000    0.000    0.000    0.000 __init__.py:585(__init__)
#         1    0.000    0.000    0.000    0.000 __init__.py:608(most_common)
#    117408    0.093    0.000    0.297    0.000 __init__.py:658(update)
#         2    0.000    0.000    0.000    0.000 cp437.py:14(decode)
#    117407    0.244    0.000    3.581    0.000 decoder.py:332(decode)
#    117407    3.156    0.000    3.156    0.000 decoder.py:343(raw_decode)
#         1    0.000    0.000    0.000    0.000 heapq.py:523(nlargest)
#         1    0.000    0.000    0.000    0.000 heapq.py:565(<listcomp>)
#         1    0.000    0.000    0.000    0.000 heapq.py:579(<listcomp>)
#         1    0.000    0.000    0.000    0.000 iostream.py:202(schedule)
#         2    0.000    0.000    0.000    0.000 iostream.py:437(_is_master_process)
#         2    0.000    0.000    0.000    0.000 iostream.py:456(_schedule_flush)
#         2    0.000    0.000    0.000    0.000 iostream.py:526(write)
#         1    0.000    0.000    0.000    0.000 iostream.py:90(_event_pipe)
#         1    0.000    0.000    0.000    0.000 socket.py:543(send)
#         1    0.000    0.000    0.000    0.000 threading.py:1118(_wait_for_tstate_lock)
#         1    0.000    0.000    0.000    0.000 threading.py:1185(is_alive)
#         1    0.000    0.000    0.000    0.000 threading.py:568(is_set)
#         1    0.000    0.000    0.000    0.000 threading.py:90(RLock)
#    106879    0.385    0.000    1.776    0.000 zipfile.py:1012(_read1)
#     14746    0.031    0.000    0.197    0.000 zipfile.py:1048(_read2)
#         1    0.000    0.000    0.000    0.000 zipfile.py:1064(close)
#         1    0.000    0.000    0.002    0.002 zipfile.py:1245(__init__)
#         1    0.000    0.000    0.000    0.000 zipfile.py:1341(__enter__)
#         1    0.000    0.000    0.000    0.000 zipfile.py:1344(__exit__)
#         1    0.000    0.000    0.001    0.001 zipfile.py:1361(_RealGetContents)
#         1    0.000    0.000    0.000    0.000 zipfile.py:1472(getinfo)
#         1    0.000    0.000    0.000    0.000 zipfile.py:1513(open)
#     14749    0.004    0.000    0.004    0.000 zipfile.py:1560(<lambda>)
#         1    0.000    0.000    0.000    0.000 zipfile.py:1872(__del__)
#         2    0.000    0.000    0.000    0.000 zipfile.py:1876(close)
#         2    0.000    0.000    0.000    0.000 zipfile.py:1992(_fpclose)
#         1    0.000    0.000    0.000    0.000 zipfile.py:242(_EndRecData64)
#         1    0.000    0.000    0.001    0.001 zipfile.py:285(_EndRecData)
#         1    0.000    0.000    0.000    0.000 zipfile.py:372(__init__)
#         1    0.000    0.000    0.000    0.000 zipfile.py:491(_decodeExtra)
#         2    0.000    0.000    0.000    0.000 zipfile.py:693(_check_compression)
#         1    0.000    0.000    0.000    0.000 zipfile.py:728(_get_decompressor)
#         1    0.000    0.000    0.000    0.000 zipfile.py:747(__init__)
#         1    0.000    0.000    0.000    0.000 zipfile.py:755(tell)
#     14749    0.044    0.000    0.155    0.000 zipfile.py:768(read)
#         1    0.000    0.000    0.000    0.000 zipfile.py:779(close)
#         1    0.000    0.000    0.000    0.000 zipfile.py:820(__init__)
#    117408    0.155    0.000    4.962    0.000 zipfile.py:896(readline)
#    770397    0.723    0.000    2.855    0.000 zipfile.py:912(peek)
#    877277    0.982    0.000    2.860    0.000 zipfile.py:930(read)
#    106879    0.065    0.000    0.223    0.000 zipfile.py:965(_update_crc)
#    117408    0.052    0.000    0.052    0.000 {built-in method _abc._abc_instancecheck}
#         2    0.000    0.000    0.000    0.000 {built-in method _codecs.charmap_decode}
#    117407    0.037    0.000    0.037    0.000 {built-in method _collections._count_elements}
#         1    0.000    0.000    0.000    0.000 {built-in method _heapq.heapify}
#         7    0.000    0.000    0.000    0.000 {built-in method _heapq.heapreplace}
#         7    0.000    0.000    0.000    0.000 {built-in method _struct.unpack}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.chr}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#    234819    0.087    0.000    0.184    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#   2542723    0.231    0.000    0.231    0.000 {built-in method builtins.len}
#    121625    0.045    0.000    0.045    0.000 {built-in method builtins.max}
#     14746    0.004    0.000    0.004    0.000 {built-in method builtins.min}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#         1    0.001    0.001    0.001    0.001 {built-in method io.open}
#         2    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#         2    0.000    0.000    0.000    0.000 {built-in method time.time}
#    106880    0.158    0.000    0.158    0.000 {built-in method zlib.crc32}
#         1    0.000    0.000    0.000    0.000 {built-in method zlib.decompressobj}
#         1    0.000    0.000    0.000    0.000 {function ZipExtFile.close at 0x000001FF059B74C0}
#     89143    1.072    0.000    4.744    0.000 {function ZipExtFile.readline at 0x000001FF059B6FC0}
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of '_io._IOBase' objects}
#     14751    0.004    0.000    0.004    0.000 {method '__exit__' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#     45636    0.006    0.000    0.006    0.000 {method 'add' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         3    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'close' of '_io.BufferedReader' objects}
#    117409    0.089    0.000    0.089    0.000 {method 'decode' of 'bytes' objects}
#    106879    0.910    0.000    0.910    0.000 {method 'decompress' of 'zlib.Decompress' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#    234814    0.029    0.000    0.029    0.000 {method 'end' of 're.Match' objects}
#    117408    0.063    0.000    0.063    0.000 {method 'find' of 'bytes' objects}
#         1    0.000    0.000    0.000    0.000 {method 'find' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'flush' of 'zlib.Decompress' objects}
#    117408    0.018    0.000    0.018    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#    117407    0.054    0.000    0.054    0.000 {method 'join' of 'str' objects}
#    234814    0.136    0.000    0.136    0.000 {method 'match' of 're.Pattern' objects}
#     14752    0.077    0.000    0.077    0.000 {method 'read' of '_io.BufferedReader' objects}
#         4    0.000    0.000    0.000    0.000 {method 'read' of '_io.BytesIO' objects}
#     14753    0.007    0.000    0.007    0.000 {method 'seek' of '_io.BufferedReader' objects}
#         1    0.000    0.000    0.000    0.000 {method 'seekable' of '_io.BufferedReader' objects}
#         1    0.000    0.000    0.000    0.000 {method 'sort' of 'list' objects}
#    117407    0.040    0.000    0.040    0.000 {method 'startswith' of 'str' objects}
#     14750    0.021    0.000    0.021    0.000 {method 'tell' of '_io.BufferedReader' objects}
#         2    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}

# %%
# =============================================================================
# Ejercicio 2: Función enfocada a la memoria
# =============================================================================

@profile
def q2_memory(file_path: str) -> List[Tuple[str, int]]:
    # Diccionario para almacenar los emojis y sus conteos
    start_time = time.time()  # Iniciar la medición de tiempo
    emoji_counts = Counter()

    # Abre el archivo ZIP
    with zipfile.ZipFile(file_path, 'r') as zip_file:
        with zip_file.open('farmers-protest-tweets-2021-2-4.json') as json_file:
            for line in json_file:
                tweet = json.loads(line.decode('utf-8'))
                tweet_text = tweet.get('content', '')
                emojis = extract_emojis(tweet_text)
                emoji_counts.update(emojis)
    
    # Obtener los 10 emojis más usados
    top_emojis = emoji_counts.most_common(10)
    end_time = time.time()  # Finalizar la medición de tiempo
    print(f"Tiempo de ejecución: {end_time - start_time} segundos")
    
    return top_emojis

# %%
# =============================================================================
# Resultados: Ejercicio 2 (memoria)
# =============================================================================
modulo_funciones_latam.q2_memory(file_path)
# Out:
# Tiempo de ejecución: 44.570900440216064 segundos
# Filename: C:\Users\bastian\modulo_funciones_latam.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#     61    181.2 MiB    181.2 MiB           1   @profile
#     62                                         def q2_memory(file_path: str) -> List[Tuple[str, int]]:
#     63                                             # Diccionario para almacenar los emojis y sus conteos
#     64    181.2 MiB      0.0 MiB           1       start_time = time.time()  # Iniciar la medición de tiempo
#     65    181.2 MiB      0.0 MiB           1       emoji_counts = Counter()
#     66
#     67                                             # Abre el archivo ZIP
#     68    181.3 MiB      0.0 MiB           2       with zipfile.ZipFile(file_path, 'r') as zip_file:
#     69    181.3 MiB     -0.0 MiB           2           with zip_file.open('farmers-protest-tweets-2021-2-4.json') as json_file:
#     70    181.3 MiB    -68.9 MiB      117408               for line in json_file:
#     71    181.3 MiB    -68.9 MiB      117407                   tweet = json.loads(line.decode('utf-8'))
#     72    181.3 MiB    -69.0 MiB      117407                   tweet_text = tweet.get('content', '')
#     73    181.3 MiB    -69.0 MiB      117407                   emojis = extract_emojis(tweet_text)
#     74    181.3 MiB    -69.0 MiB      117407                   emoji_counts.update(emojis)
#     75
#     76                                             # Obtener los 10 emojis más usados
#     77    181.3 MiB      0.0 MiB           1       top_emojis = emoji_counts.most_common(10)
#     78    181.3 MiB      0.0 MiB           1       end_time = time.time()  # Finalizar la medición de tiempo
#     79    181.3 MiB      0.0 MiB           1       print(f"Tiempo de ejecución: {end_time - start_time} segundos")
#     80
#     81    181.3 MiB      0.0 MiB           1       return top_emojis
# [('🙏', 4529),
#  ('✊', 1724),
#  ('❤', 1471),
#  ('😂', 1387),
#  ('🌾', 1377),
#  ('🚜', 1334),
#  ('🏻', 1010),
#  ('🏽', 938),
#  ('🤣', 759),
#  ('👇', 712)]

# %% [markdown]
# # Ejercicio 3: El top 10 histórico de usuarios más influyentes en función del conteo de las menciones que registra cada uno de ellos.

# %%
# =============================================================================
# Ejercicio 3: Función enfocada al timepo
# =============================================================================
from collections import defaultdict

def q3_time(file_path: str) -> List[Tuple[str, int]]:
    start_time = time.time()  # Iniciar la medición de tiempo
    user_mentions_count = defaultdict(int)

    # Abre el archivo ZIP y analiza el contenido JSON línea por línea
    with zipfile.ZipFile(file_path, 'r') as zip_file:
        with zip_file.open('farmers-protest-tweets-2021-2-4.json') as json_file:
            for line in json_file:
                line
                # break
                tweet = json.loads(line.decode('utf-8'))
                username = tweet.get("user", {}).get("username", "")
                mentioned_users = tweet.get("mentionedUsers", [])
                if mentioned_users is not None:
                    user_mentions_count[username] += len(mentioned_users)

    # Obtener el top 10 de usuarios con más menciones
    top_users = sorted(user_mentions_count.items(), key=lambda x: x[1], reverse=True)[:10]

    end_time = time.time()  # Finalizar la medición de tiempo
    print(f"Tiempo de ejecución q3_time: {end_time - start_time} segundos")

    return top_users

# %%
# =============================================================================
# Resultados: Ejercicio 3 (tiempo)
# =============================================================================
if __name__ == "__main__":
    profiler = cProfile.Profile()
    result = profiler.runcall(q3_time, file_path)
    print(result)
    print("\n")
    profiler.print_stats()
# Out:
# Tiempo de ejecución q3_time: 10.359294891357422 segundos
# [('loyal90901246', 2478), ('_gurviir', 1826), ('neetuanjle_nitu', 1792), ('JaiHind58236291', 1696), ('preetysaini321', 927), ('JoyJ69957841', 915), ('Gurpreetd86', 842), ('jot__b', 839), ('mani262002', 777), ('ScitaramSays', 762)]
#
#
#          6756728 function calls in 10.359 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     10823    0.001    0.000    0.001    0.000 237433633.py:22(<lambda>)
#         1    0.602    0.602   10.359   10.359 237433633.py:5(q3_time)
#         1    0.000    0.000    0.000    0.000 <frozen abc>:117(__instancecheck__)
#    117407    0.171    0.000    4.129    0.000 __init__.py:299(loads)
#         2    0.000    0.000    0.000    0.000 cp437.py:14(decode)
#    117407    0.260    0.000    3.899    0.000 decoder.py:332(decode)
#    117407    3.441    0.000    3.441    0.000 decoder.py:343(raw_decode)
#         1    0.000    0.000    0.000    0.000 iostream.py:202(schedule)
#         2    0.000    0.000    0.000    0.000 iostream.py:437(_is_master_process)
#         2    0.000    0.000    0.000    0.000 iostream.py:456(_schedule_flush)
#         2    0.000    0.000    0.000    0.000 iostream.py:526(write)
#         1    0.000    0.000    0.000    0.000 iostream.py:90(_event_pipe)
#         1    0.000    0.000    0.000    0.000 socket.py:543(send)
#         1    0.000    0.000    0.000    0.000 threading.py:1118(_wait_for_tstate_lock)
#         1    0.000    0.000    0.000    0.000 threading.py:1185(is_alive)
#         1    0.000    0.000    0.000    0.000 threading.py:568(is_set)
#         1    0.000    0.000    0.000    0.000 threading.py:90(RLock)
#    106879    0.413    0.000    1.956    0.000 zipfile.py:1012(_read1)
#     14746    0.035    0.000    0.241    0.000 zipfile.py:1048(_read2)
#         1    0.000    0.000    0.000    0.000 zipfile.py:1064(close)
#         1    0.000    0.000    0.002    0.002 zipfile.py:1245(__init__)
#         1    0.000    0.000    0.000    0.000 zipfile.py:1341(__enter__)
#         1    0.000    0.000    0.000    0.000 zipfile.py:1344(__exit__)
#         1    0.000    0.000    0.001    0.001 zipfile.py:1361(_RealGetContents)
#         1    0.000    0.000    0.000    0.000 zipfile.py:1472(getinfo)
#         1    0.000    0.000    0.000    0.000 zipfile.py:1513(open)
#     14749    0.005    0.000    0.005    0.000 zipfile.py:1560(<lambda>)
#         1    0.000    0.000    0.000    0.000 zipfile.py:1872(__del__)
#         2    0.000    0.000    0.000    0.000 zipfile.py:1876(close)
#         2    0.000    0.000    0.000    0.000 zipfile.py:1992(_fpclose)
#         1    0.000    0.000    0.000    0.000 zipfile.py:242(_EndRecData64)
#         1    0.000    0.000    0.001    0.001 zipfile.py:285(_EndRecData)
#         1    0.000    0.000    0.000    0.000 zipfile.py:372(__init__)
#         1    0.000    0.000    0.000    0.000 zipfile.py:491(_decodeExtra)
#         2    0.000    0.000    0.000    0.000 zipfile.py:693(_check_compression)
#         1    0.000    0.000    0.000    0.000 zipfile.py:728(_get_decompressor)
#         1    0.000    0.000    0.000    0.000 zipfile.py:747(__init__)
#         1    0.000    0.000    0.000    0.000 zipfile.py:755(tell)
#     14749    0.051    0.000    0.194    0.000 zipfile.py:768(read)
#         1    0.000    0.000    0.000    0.000 zipfile.py:779(close)
#         1    0.000    0.000    0.000    0.000 zipfile.py:820(__init__)
#    117408    0.167    0.000    5.463    0.000 zipfile.py:896(readline)
#    770397    0.784    0.000    3.120    0.000 zipfile.py:912(peek)
#    877277    1.064    0.000    3.127    0.000 zipfile.py:930(read)
#    106879    0.072    0.000    0.243    0.000 zipfile.py:965(_update_crc)
#         1    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#         2    0.000    0.000    0.000    0.000 {built-in method _codecs.charmap_decode}
#         7    0.000    0.000    0.000    0.000 {built-in method _struct.unpack}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.chr}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#    117412    0.017    0.000    0.017    0.000 {built-in method builtins.isinstance}
#   2580756    0.249    0.000    0.249    0.000 {built-in method builtins.len}
#    121625    0.048    0.000    0.048    0.000 {built-in method builtins.max}
#     14746    0.004    0.000    0.004    0.000 {built-in method builtins.min}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#         1    0.004    0.004    0.005    0.005 {built-in method builtins.sorted}
#         1    0.001    0.001    0.001    0.001 {built-in method io.open}
#         2    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#         2    0.000    0.000    0.000    0.000 {built-in method time.time}
#    106880    0.172    0.000    0.172    0.000 {built-in method zlib.crc32}
#         1    0.000    0.000    0.000    0.000 {built-in method zlib.decompressobj}
#         1    0.000    0.000    0.000    0.000 {function ZipExtFile.close at 0x000001FF059B74C0}
#     89143    1.228    0.000    5.232    0.000 {function ZipExtFile.readline at 0x000001FF059B6FC0}
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of '_io._IOBase' objects}
#     14751    0.004    0.000    0.004    0.000 {method '__exit__' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         3    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'close' of '_io.BufferedReader' objects}
#    117409    0.103    0.000    0.103    0.000 {method 'decode' of 'bytes' objects}
#    106879    0.993    0.000    0.993    0.000 {method 'decompress' of 'zlib.Decompress' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#    234814    0.032    0.000    0.032    0.000 {method 'end' of 're.Match' objects}
#    117408    0.064    0.000    0.064    0.000 {method 'find' of 'bytes' objects}
#         1    0.000    0.000    0.000    0.000 {method 'find' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'flush' of 'zlib.Decompress' objects}
#    352222    0.050    0.000    0.050    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#    234814    0.147    0.000    0.147    0.000 {method 'match' of 're.Pattern' objects}
#     14752    0.101    0.000    0.101    0.000 {method 'read' of '_io.BufferedReader' objects}
#         4    0.000    0.000    0.000    0.000 {method 'read' of '_io.BytesIO' objects}
#     14753    0.009    0.000    0.009    0.000 {method 'seek' of '_io.BufferedReader' objects}
#         1    0.000    0.000    0.000    0.000 {method 'seekable' of '_io.BufferedReader' objects}
#    117407    0.042    0.000    0.042    0.000 {method 'startswith' of 'str' objects}
#     14750    0.025    0.000    0.025    0.000 {method 'tell' of '_io.BufferedReader' objects}
#         2    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}

# %%
# =============================================================================
# Ejercicio 3: Función enfocada a la memoria
# =============================================================================
@profile
def q3_memory(file_path: str) -> List[Tuple[str, int]]:
    start_time = time.time()  # Iniciar la medición de tiempo

    user_mentions_count = defaultdict(int)

    # Abre el archivo ZIP y analiza el contenido JSON línea por línea
    with zipfile.ZipFile(file_path, 'r') as zip_file:
        with zip_file.open('farmers-protest-tweets-2021-2-4.json') as json_file:
            for line in json_file:
                tweet = json.loads(line.decode('utf-8'))
                username = tweet.get("user", {}).get("username", "")
                mentioned_users = tweet.get("mentionedUsers", [])
                if mentioned_users is not None:
                    user_mentions_count[username] += len(mentioned_users)

    # Obtener el top 10 de usuarios con más menciones
    top_users = sorted(user_mentions_count.items(), key=lambda x: x[1], reverse=True)[:10]
    end_time = time.time()  # Finalizar la medición de tiempo
    print(f"Tiempo de ejecución q3_time: {end_time - start_time} segundos")

    return top_users

# %%
# =============================================================================
# Resultados: Ejercicio 3 (memoria)
# =============================================================================
modulo_funciones_latam.q3_memory(file_path)
# Out:
# Tiempo de ejecución q3_time: 31.395042419433594 segundos
# Filename: C:\Users\bastian\modulo_funciones_latam.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#     88    138.9 MiB    138.9 MiB           1   @profile
#     89                                         def q3_memory(file_path: str) -> List[Tuple[str, int]]:
#     90    138.9 MiB      0.0 MiB           1       start_time = time.time()  # Iniciar la medición de tiempo
#     91
#     92    138.9 MiB      0.0 MiB           1       user_mentions_count = defaultdict(int)
#     93
#     94                                             # Abre el archivo ZIP y analiza el contenido JSON línea por línea
#     95    140.4 MiB      0.0 MiB           2       with zipfile.ZipFile(file_path, 'r') as zip_file:
#     96    140.4 MiB      0.0 MiB           2           with zip_file.open('farmers-protest-tweets-2021-2-4.json') as json_file:
#     97    140.4 MiB   -103.7 MiB      117408               for line in json_file:
#     98    140.4 MiB   -103.7 MiB      117407                   tweet = json.loads(line.decode('utf-8'))
#     99    140.4 MiB   -104.5 MiB      117407                   username = tweet.get("user", {}).get("username", "")
#    100    140.4 MiB   -104.5 MiB      117407                   mentioned_users = tweet.get("mentionedUsers", [])
#    101    140.4 MiB   -104.5 MiB      117407                   if mentioned_users is not None:
#    102    140.4 MiB    -33.3 MiB       38034                       user_mentions_count[username] += len(mentioned_users)
#    103
#    104                                             # Obtener el top 10 de usuarios con más menciones
#    105    140.9 MiB      0.5 MiB       21647       top_users = sorted(user_mentions_count.items(), key=lambda x: x[1], reverse=True)[:10]
#    106    140.9 MiB      0.0 MiB           1       end_time = time.time()  # Finalizar la medición de tiempo
#    107    140.9 MiB      0.0 MiB           1       print(f"Tiempo de ejecución q3_time: {end_time - start_time} segundos")
#    108
#    109    140.9 MiB      0.0 MiB           1       return top_users
# [('loyal90901246', 2478),
#  ('_gurviir', 1826),
#  ('neetuanjle_nitu', 1792),
#  ('JaiHind58236291', 1696),
#  ('preetysaini321', 927),
#  ('JoyJ69957841', 915),
#  ('Gurpreetd86', 842),
#  ('jot__b', 839),
#  ('mani262002', 777),
#  ('ScitaramSays', 762)]
